# %%
import sys
import numpy as np
import pickle
sys.path.insert(0, '../cell_soap/')
from cell_describe import node, edge, cell, colony, data, manual_tracing, surface_evolver,manual_tracing_multiple

# %%
with open('quantius_data.csv', 'r') as f:
#     print([a for a in f])
# with open('ritvik_cellfit_edges[111,112,113,114]_tensions_2.noneq_1.fe.txt', 'r') as f:
    a = [l.split('\n') for l in f]

# %%
import csv
with open('quantius_data.csv') as csvfile:
    reader = csv.DictReader(csvfile)
    x,y = [],[]
    for row in reader:
        print(row[None])
        kk = row[None][0]
        print(kk)
# Out:
# ["[{'y': 95, 'x': 142}, {'y': 74, 'x': 131}, {'y': 56, 'x': 151}]"]
# [{'y': 95, 'x': 142}, {'y': 74, 'x': 131}, {'y': 56, 'x': 151}]
# ["[{'y': 37, 'x': 98}, {'y': 34, 'x': 113}, {'y': 21, 'x': 113}, {'y': 12, 'x': 88}, {'y': 18, 'x': 84}, {'y': 35, 'x': 102}, {'y': 49, 'x': 92}, {'y': 57, 'x': 84}, {'y': 64, 'x': 97}, {'y': 67, 'x': 108}, {'y': 47, 'x': 113}, {'y': 38, 'x': 113}, {'y': 53, 'x': 116}, {'y': 66, 'x': 143}, {'y': 43, 'x': 145}, {'y': 31, 'x': 145}, {'y': 28, 'x': 130}, {'y': 23, 'x': 119}, {'y': 23, 'x': 119}, {'y': 21, 'x': 117}]"]
# [{'y': 37, 'x': 98}, {'y': 34, 'x': 113}, {'y': 21, 'x': 113}, {'y': 12, 'x': 88}, {'y': 18, 'x': 84}, {'y': 35, 'x': 102}, {'y': 49, 'x': 92}, {'y': 57, 'x': 84}, {'y': 64, 'x': 97}, {'y': 67, 'x': 108}, {'y': 47, 'x': 113}, {'y': 38, 'x': 113}, {'y': 53, 'x': 116}, {'y': 66, 'x': 143}, {'y': 43, 'x': 145}, {'y': 31, 'x': 145}, {'y': 28, 'x': 130}, {'y': 23, 'x': 119}, {'y': 23, 'x': 119}, {'y': 21, 'x': 117}]
# ...
