# %%
# import packages

import pickle, pprint
import numpy as np
import matplotlib.pyplot as plt
import collections
import sys
import numpy.linalg as la
sys.path.insert(0, '../cell_soap/')
from cell_describe import node, edge, cell, colony, data, data_multiple

# %% [markdown]
# # Load data into data_multiple class

# %%
# data_multiple(data)
pkl_file = open('zo1_graph_timelapse_sample_v2.pkl','rb')
data1 = pickle.load(pkl_file)
pkl = data_multiple(data1)

# %% [markdown]
# # Compute results

# %%
#  Choose time and cutoff
# problems - 16, 
t = 30
cutoff = 1

# %%
# 5 outputs - colony, tensions, pressures, tension-matrix, pressure-matrix
# pkl.compute(time, cutoff)
a, b, c,d, e = pkl.compute(t, cutoff)
print(la.cond(d))
if e is not None:
    print(la.cond(e))
# Out:
# 1203.4025078653801
# 3.215727049246505e+16
# ../cell_soap/cell_describe.py:606: LinAlgWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number8.623177e-19
#   x = linalg.solve(R2, y) # Solve Rx=y

# %% [markdown]
# # Plot results

# %%
# pkl.plot only plots tensions for now because pressures seem singular

fig, ax = plt.subplots(1,1, figsize = (8,5))
# pkl.plot(ax, fig, time, cutoff)
pkl.plot(ax, fig, t, cutoff, lw = 20)

# %%
# Plot cells 
fig, ax1 = plt.subplots(1,1, figsize = (8,5))
#pkl.plot_cells(ax, t, cutoff)
pkl.plot_cells(ax1, t, cutoff)

# %%
# Plot image 
fig, (ax, ax1) = plt.subplots(1,2, figsize = (15,5))
V = data(pkl.pkl, t)
V.plot(ax, type = "image")
V.plot(ax1, type = "edge_and_nodes")

# %% [markdown]
# # Save pictures

# %%
fig, ax = plt.subplots(1,1, figsize = (8,5))
# pkl.save_pictures(ax, fig, max_time, cutoff)
pkl.save_pictures(ax, fig, 30, 1)
# Out:
# ../cell_soap/cell_describe.py:621: LinAlgWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number5.289866e-19
#   x = linalg.solve(R2, y) # Solve Rx=y
# ../cell_soap/cell_describe.py:621: LinAlgWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number1.448204e-18
#   x = linalg.solve(R2, y) # Solve Rx=y
# ../cell_soap/cell_describe.py:621: LinAlgWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number1.172696e-18
#   x = linalg.solve(R2, y) # Solve Rx=y
# ../cell_soap/cell_describe.py:621: LinAlgWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number6.875968e-19
#   x = linalg.solve(R2, y) # Solve Rx=y
# ../cell_soap/cell_describe.py:621: LinAlgWarning: scipy.linalg.solve
# ...

# %% [markdown]
# # Make a movie

# %%
fig, ax = plt.subplots(1,1, figsize = (8,5))
# pkl.createmovie(ax, fig, max_frame_number, cutoff)
pkl.CreateMovie(ax, fig, 31, 1)
# Out:
# ../cell_soap/cell_describe.py:621: LinAlgWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number5.289866e-19
#   x = linalg.solve(R2, y) # Solve Rx=y
# ../cell_soap/cell_describe.py:621: LinAlgWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number1.448204e-18
#   x = linalg.solve(R2, y) # Solve Rx=y
# ../cell_soap/cell_describe.py:621: LinAlgWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number1.172696e-18
#   x = linalg.solve(R2, y) # Solve Rx=y
# ../cell_soap/cell_describe.py:621: LinAlgWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number6.875968e-19
#   x = linalg.solve(R2, y) # Solve Rx=y
# ../cell_soap/cell_describe.py:621: LinAlgWarning: scipy.linalg.solve
# ...

# %%
pkl.CreateMovie?
